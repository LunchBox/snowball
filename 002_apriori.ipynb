# %%
from IPython.display import display

from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules

import pandas as pd
import yfinance as yf

import time

# %%
data = [
	['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
	['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
	['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
	['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
	['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']
]

# %%
enc = TransactionEncoder()
arr = enc.fit(data).transform(data)

display(arr)
# Out:
# array([[False, False, False,  True, False,  True,  True,  True,  True,
#         False,  True],
#        [False, False,  True,  True, False,  True, False,  True,  True,
#         False,  True],
#        [ True, False, False,  True, False,  True,  True, False, False,
#         False, False],
#        [False,  True, False, False, False,  True,  True, False, False,
#          True,  True],
#        [False,  True, False,  True,  True,  True, False, False,  True,
#         False, False]])

# %%
display(enc.columns_)
# Out:
# ['Apple',
#  'Corn',
#  'Dill',
#  'Eggs',
#  'Ice cream',
#  'Kidney Beans',
#  'Milk',
#  'Nutmeg',
#  'Onion',
#  'Unicorn',
#  'Yogurt']

# %%
df = pd.DataFrame(arr, columns = enc.columns_)
display(df)
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
res = apriori(df, min_support=0.3, use_colnames=True, max_len=4)

f_res = res[res['itemsets'].map(len) > 1].sort_values('support', ascending=False)

display(f_res)
# Out:
#     support                               itemsets
# 8       0.8                   (Kidney Beans, Eggs)
# 16      0.6                 (Yogurt, Kidney Beans)
# 23      0.6            (Onion, Kidney Beans, Eggs)
# 11      0.6                          (Onion, Eggs)
# 13      0.6                   (Milk, Kidney Beans)
# 15      0.6                  (Onion, Kidney Beans)
# 31      0.4          (Yogurt, Onion, Kidney Beans)
# 28      0.4           (Milk, Yogurt, Kidney Beans)
# 29      0.4          (Onion, Kidney Beans, Nutmeg)
# 30      0.4         (Yogurt, Kidney Beans, Nutmeg)
# 7       0.4                   (Corn, Kidney Beans)
# 32      0.4                (Yogurt, Onion, Nutmeg)
# 26      0.4                 (Nutmeg, Yogurt, Eggs)
# 33      0.4    (Nutmeg, Onion, Kidney Beans, Eggs)
# 34      0.4   (Nutmeg, Yogurt, Kidney Beans, Eggs)
# 35      0.4    (Yogurt, Onion, Kidney Beans, Eggs)
# 36      0.4          (Nutmeg, Yogurt, Onion, Eggs)
# 27      0.4                  (Yogurt, Onion, Eggs)
# 22      0.4           (Nutmeg, Kidney Beans, Eggs)
# 25      0.4                  (Nutmeg, Onion, Eggs)
# 24      0.4           (Yogurt, Kidney Beans, Eggs)
# 21      0.4             (Milk, Kidney Beans, Eggs)
# 20      0.4                        (Yogurt, Onion)
# 19      0.4                       (Yogurt, Nutmeg)
# 18      0.4                        (Onion, Nutmeg)
# 17      0.4                         (Milk, Yogurt)
# 14      0.4                 (Kidney Beans, Nutmeg)
# 12      0.4                         (Yogurt, Eggs)
# 10      0.4                         (Nutmeg, Eggs)
# 9       0.4                           (Milk, Eggs)
# 37      0.4  (Yogurt, Onion, Kidney Beans, Nutmeg)

# %%
tickers = ['^SPX', 'NVDA', 'MSFT', 'AAPL', 'META']

df = yf.download(
    tickers, 
    start="2023-01-01", 
    end="2023-12-31", 
    interval="1d", 
    group_by='Ticker'
)

display(df)
# Out:
# /Users/kimfaicheang/workspace/snowball/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /Users/kimfaicheang/workspace/snowball/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]/Users/kimfaicheang/workspace/snowball/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]/Users/kimfaicheang/workspace/snowball/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /Users/kimfaicheang/workspace/snowball/venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]
    
    close.name = t
    closes.append(close)

df = pd.concat(closes, axis=1)

display(df)
# Out:
#                  ^SPX       NVDA       MSFT       AAPL       META
# Date
# 2023-01-03  ^SPX DOWN  NVDA DOWN  MSFT DOWN  AAPL DOWN  META DOWN
# 2023-01-04    ^SPX UP    NVDA UP  MSFT DOWN    AAPL UP    META UP
# 2023-01-05  ^SPX DOWN  NVDA DOWN  MSFT DOWN  AAPL DOWN  META DOWN
# 2023-01-06    ^SPX UP    NVDA UP    MSFT UP    AAPL UP    META UP
# 2023-01-09  ^SPX DOWN    NVDA UP    MSFT UP    AAPL UP  META DOWN
# ...               ...        ...        ...        ...        ...
# 2023-12-22    ^SPX UP  NVDA DOWN    MSFT UP  AAPL DOWN  META DOWN
# 2023-12-26    ^SPX UP    NVDA UP    MSFT UP  AAPL DOWN    META UP
# 2023-12-27    ^SPX UP    NVDA UP  MSFT DOWN    AAPL UP    META UP
# 2023-12-28    ^SPX UP    NVDA UP    MSFT UP    AAPL UP    META UP
# 2023-12-29  ^SPX DOWN  NVDA DOWN    MSFT UP  AAPL DOWN  META DOWN
#
# [250 rows x 5 columns]

# %%
spx = df[['^SPX']][1:].reset_index(drop=True)

rest = df.loc[:, df.columns != '^SPX'][:-1].reset_index(drop=True)

df = pd.concat([spx, rest], axis=1)
display(df)
# Out:
#           ^SPX       NVDA       MSFT       AAPL       META
# 0      ^SPX UP  NVDA DOWN  MSFT DOWN  AAPL DOWN  META DOWN
# 1    ^SPX DOWN    NVDA UP  MSFT DOWN    AAPL UP    META UP
# 2      ^SPX UP  NVDA DOWN  MSFT DOWN  AAPL DOWN  META DOWN
# 3    ^SPX DOWN    NVDA UP    MSFT UP    AAPL UP    META UP
# 4      ^SPX UP    NVDA UP    MSFT UP    AAPL UP  META DOWN
# ..         ...        ...        ...        ...        ...
# 244    ^SPX UP    NVDA UP    MSFT UP  AAPL DOWN    META UP
# 245    ^SPX UP  NVDA DOWN    MSFT UP  AAPL DOWN  META DOWN
# 246    ^SPX UP    NVDA UP    MSFT UP  AAPL DOWN    META UP
# 247    ^SPX UP    NVDA UP  MSFT DOWN    AAPL UP    META UP
# 248  ^SPX DOWN    NVDA UP    MSFT UP    AAPL UP    META UP
#
# [249 rows x 5 columns]

# %%
data = df.values

enc = TransactionEncoder()
arr = enc.fit(data).transform(data)

df = pd.DataFrame(arr, columns = enc.columns_)

start_time = time.time()

res = apriori(df, min_support=0.3, use_colnames=True, max_len=4)

print("--- run time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- run time: 0.0025720596313476562 seconds ---

# %%
def contain_spx(list): 
	return any(item.startswith("^SPX") for item in list)

# %%
f_res = res[res['itemsets'].map(len) > 1]

f_res = f_res[f_res['itemsets'].apply(contain_spx)].sort_values('support', ascending=False)

display(f_res)
# Out:
#      support            itemsets
# 21  0.337349  (NVDA UP, ^SPX UP)
# 20  0.321285  (^SPX UP, MSFT UP)

# %%
rules = association_rules(res, metric="confidence", min_threshold=0.5)
rules = rules[rules['consequents'].apply(contain_spx)]
display(rules)
# Out:
#    antecedents consequents  antecedent support  consequent support   support  \
# 21   (MSFT UP)   (^SPX UP)            0.546185            0.550201  0.321285
# 22   (NVDA UP)   (^SPX UP)            0.570281            0.550201  0.337349
#
#     confidence      lift  leverage  conviction  zhangs_metric
# 21    0.588235  1.069128  0.020774    1.092369       0.142478
# 22    0.591549  1.075152  0.023580    1.101233       0.162661
