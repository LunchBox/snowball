# %% [markdown]
# 關聯統計算法是一種用於分析數據集中變數之間關聯性的統計方法。它主要用於發現變數之間的相關性、依賴性或聯繫性，以及識別出可能的關聯規則。其中最著名且常用的關聯統計算法是關聯規則挖掘，其中包括 Apriori 算法和FP-Growth 算法。

# %%
from efficient_apriori import apriori

import pandas as pd
import yfinance as yf

import time

# %%
data = [
	['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
	['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
	['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
	['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
	['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']
]

# %%
itemsets, rules = apriori(data, min_support=0.5,  min_confidence=1) 
rules
# Out:
# [{Eggs} -> {Kidney Beans},
#  {Onion} -> {Eggs},
#  {Milk} -> {Kidney Beans},
#  {Onion} -> {Kidney Beans},
#  {Yogurt} -> {Kidney Beans},
#  {Kidney Beans, Onion} -> {Eggs},
#  {Eggs, Onion} -> {Kidney Beans},
#  {Onion} -> {Eggs, Kidney Beans}]

# %% [markdown]
# ## try on stocks

# %% [markdown]
# 我們的想法是構造一些事件「一起發生」的場景數據集，用關聯算法幫我們找出常見的經常一起發生的事件，例如將當日各項股票的升跌，和第二日各項股票的升跌，看成是「一起發生」的相同場景。

# %%
tickers = ['^SPX', 'NVDA', 'MSFT', 'AAPL', 'META']

df = yf.download(tickers, period="60d", interval="5m")

df["Close"]
# Out:
# [*********************100%%**********************]  5 of 5 completed
# Ticker                           AAPL        META        MSFT        NVDA  \
# Datetime
# 2023-11-21 09:30:00-05:00  191.210007  338.059998  374.934998  502.459991
# 2023-11-21 09:35:00-05:00  190.919998  338.605499  375.749390  504.260010
# 2023-11-21 09:40:00-05:00  190.764999  338.660004  376.000000  503.135010
# 2023-11-21 09:45:00-05:00  190.919998  338.839996  375.214996  500.510010
# 2023-11-21 09:50:00-05:00  191.021194  339.184998  375.720001  501.600006
# ...                               ...         ...         ...         ...
# 2024-02-16 15:35:00-05:00  182.119995  473.484985  404.149994  730.851990
# 2024-02-16 15:40:00-05:00  182.054993  473.290100  403.910004  728.770020
# 2024-02-16 15:45:00-05:00  181.735001  472.170013  403.769989  725.760010
# 2024-02-16 15:50:00-05:00  181.964005  473.390015  403.703094  727.234985
# 2024-02-16 15:55:00-05:00  182.289993  473.100006  404.059998  726.005005
#
# Ticker                            ^SPX
# Datetime
# 2023-11-21 09:30:00-05:00          NaN
# 2023-11-21 09:35:00-05:00          NaN
# 2023-11-21 09:40:00-05:00          NaN
# 2023-11-21 09:45:00-05:00          NaN
# 2023-11-21 09:50:00-05:00          NaN
# ...                                ...
# 2024-02-16 15:35:00-05:00  5012.060059
# 2024-02-16 15:40:00-05:00  5006.509766
# 2024-02-16 15:45:00-05:00  5000.839844
# 2024-02-16 15:50:00-05:00  5005.089844
# 2024-02-16 15:55:00-05:00  5005.149902
#
# [4642 rows x 5 columns]

# %% [markdown]
# yf 預設用 Open, Close ... 分組，用 df.Close 或 df['Close'] 取出所有的 Close 欄

# %%
data = df['Close'].fillna(0)

updown = data.diff().apply(lambda r: r.apply(lambda x: r.name + '_UP' if x > 0 else r.name + '_DOWN'))

updown
# Out:
# Ticker                          AAPL       META       MSFT       NVDA  \
# Datetime
# 2023-11-21 09:30:00-05:00  AAPL_DOWN  META_DOWN  MSFT_DOWN  NVDA_DOWN
# 2023-11-21 09:35:00-05:00  AAPL_DOWN    META_UP    MSFT_UP    NVDA_UP
# 2023-11-21 09:40:00-05:00  AAPL_DOWN    META_UP    MSFT_UP  NVDA_DOWN
# 2023-11-21 09:45:00-05:00    AAPL_UP    META_UP  MSFT_DOWN  NVDA_DOWN
# 2023-11-21 09:50:00-05:00    AAPL_UP    META_UP    MSFT_UP    NVDA_UP
# ...                              ...        ...        ...        ...
# 2024-02-16 15:35:00-05:00  AAPL_DOWN    META_UP  MSFT_DOWN  NVDA_DOWN
# 2024-02-16 15:40:00-05:00  AAPL_DOWN  META_DOWN  MSFT_DOWN  NVDA_DOWN
# 2024-02-16 15:45:00-05:00  AAPL_DOWN  META_DOWN  MSFT_DOWN  NVDA_DOWN
# 2024-02-16 15:50:00-05:00    AAPL_UP    META_UP  MSFT_DOWN    NVDA_UP
# 2024-02-16 15:55:00-05:00    AAPL_UP  META_DOWN    MSFT_UP  NVDA_DOWN
#
# Ticker                          ^SPX
# Datetime
# 2023-11-21 09:30:00-05:00  ^SPX_DOWN
# 2023-11-21 09:35:00-05:00  ^SPX_DOWN
# 2023-11-21 09:40:00-05:00  ^SPX_DOWN
# 2023-11-21 09:45:00-05:00  ^SPX_DOWN
# 2023-11-21 09:50:00-05:00  ^SPX_DOWN
# ...                              ...
# 2024-02-16 15:35:00-05:00  ^SPX_DOWN
# 2024-02-16 15:40:00-05:00  ^SPX_DOWN
# 2024-02-16 15:45:00-05:00  ^SPX_DOWN
# 2024-02-16 15:50:00-05:00    ^SPX_UP
# 2024-02-16 15:55:00-05:00    ^SPX_UP
#
# [4642 rows x 5 columns]

# %% [markdown]
# 根據每日相對於前一日的升跌，將數字轉為 label

# %%
updown['Next ^SPX'] = "N_" + updown['^SPX'].shift(-1)

updown = updown[:-1]

updown
# Out:
# Ticker                          AAPL       META       MSFT       NVDA  \
# Datetime
# 2023-11-21 09:30:00-05:00  AAPL_DOWN  META_DOWN  MSFT_DOWN  NVDA_DOWN
# 2023-11-21 09:35:00-05:00  AAPL_DOWN    META_UP    MSFT_UP    NVDA_UP
# 2023-11-21 09:40:00-05:00  AAPL_DOWN    META_UP    MSFT_UP  NVDA_DOWN
# 2023-11-21 09:45:00-05:00    AAPL_UP    META_UP  MSFT_DOWN  NVDA_DOWN
# 2023-11-21 09:50:00-05:00    AAPL_UP    META_UP    MSFT_UP    NVDA_UP
# ...                              ...        ...        ...        ...
# 2024-02-16 15:30:00-05:00  AAPL_DOWN  META_DOWN    MSFT_UP  NVDA_DOWN
# 2024-02-16 15:35:00-05:00  AAPL_DOWN    META_UP  MSFT_DOWN  NVDA_DOWN
# 2024-02-16 15:40:00-05:00  AAPL_DOWN  META_DOWN  MSFT_DOWN  NVDA_DOWN
# 2024-02-16 15:45:00-05:00  AAPL_DOWN  META_DOWN  MSFT_DOWN  NVDA_DOWN
# 2024-02-16 15:50:00-05:00    AAPL_UP    META_UP  MSFT_DOWN    NVDA_UP
#
# Ticker                          ^SPX    Next ^SPX
# Datetime
# 2023-11-21 09:30:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2023-11-21 09:35:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2023-11-21 09:40:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2023-11-21 09:45:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2023-11-21 09:50:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# ...                              ...          ...
# 2024-02-16 15:30:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2024-02-16 15:35:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2024-02-16 15:40:00-05:00  ^SPX_DOWN  N_^SPX_DOWN
# 2024-02-16 15:45:00-05:00  ^SPX_DOWN    N_^SPX_UP
# 2024-02-16 15:50:00-05:00    ^SPX_UP    N_^SPX_UP
#
# [4641 rows x 6 columns]

# %% [markdown]
# 將第二日 SPX 的升跌往上移動一格，各項股票的升跌就和第二日發生 SPX 升跌出現在同一行裡，相當於「一起發生」。
#
# 最後一行沒有第二日的數據，去掉

# %%
start_time = time.time()
itemsets, rules = apriori(updown.values, min_support=0.2,  min_confidence=0.5)
print("--- run time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- run time: 0.02684187889099121 seconds ---

# %%
rules_rhs = filter(lambda rule: len(rule.lhs) == 1 and rule.rhs[0].startswith('N_'), rules)

# %% [markdown]
# 只關注目標事件為第二日 SPX 的升跌，即 N_^SPX_UP 或者 N_^SPX_DOWN

# %%
for rule in sorted(rules_rhs, key=lambda rule: rule.confidence, reverse=True):
  print(rule)
# Out:
# {^SPX_UP} -> {N_^SPX_UP} (conf: 0.522, supp: 0.265, lift: 1.028, conv: 1.030)
# {META_DOWN} -> {N_^SPX_UP} (conf: 0.521, supp: 0.259, lift: 1.026, conv: 1.028)
# {AAPL_DOWN} -> {N_^SPX_UP} (conf: 0.518, supp: 0.252, lift: 1.019, conv: 1.020)
# {NVDA_UP} -> {N_^SPX_UP} (conf: 0.516, supp: 0.268, lift: 1.015, conv: 1.016)
# {MSFT_UP} -> {N_^SPX_UP} (conf: 0.509, supp: 0.263, lift: 1.002, conv: 1.002)
# {MSFT_DOWN} -> {N_^SPX_UP} (conf: 0.507, supp: 0.245, lift: 0.998, conv: 0.998)
# {^SPX_DOWN} -> {N_^SPX_DOWN} (conf: 0.506, supp: 0.249, lift: 1.030, conv: 1.030)
# {META_UP} -> {N_^SPX_DOWN} (conf: 0.505, supp: 0.254, lift: 1.026, conv: 1.026)
# {AAPL_UP} -> {N_^SPX_DOWN} (conf: 0.501, supp: 0.257, lift: 1.018, conv: 1.018)
# {NVDA_DOWN} -> {N_^SPX_DOWN} (conf: 0.500, supp: 0.240, lift: 1.017, conv: 1.017)
# {NVDA_DOWN} -> {N_^SPX_UP} (conf: 0.500, supp: 0.240, lift: 0.984, conv: 0.983)

# %% [markdown]
# 兩個概念：support 和 confidence
#
# - support 是指在所有發生的場景中，兩者同時發生的次數，即 support(A -> B) = count(A & B) / count(ALL)
# - confidence 是指在 A 發生的場景中，B 發生的次數， 即 support(A -> B) = count(A & B) / count(A)

# %% [markdown]
# 最終結果以 confidence 做排序，發現單一因子對於 SPX 升跌的確信度都很靠前，很少出現多因子
